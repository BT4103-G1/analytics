# %%
from preprocess import preprocess
train_filepath = "CMaps/train_FD001.txt"
test_filepath = "CMaps/test_FD001.txt"
preprocess(train_filepath, test_filepath)
# Out:
# Train: (20631, 28)
# Test: (13096, 28)
# df: (33727, 28)
