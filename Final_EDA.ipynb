# %% [markdown]
# ## Data Paths
# > Insert file paths of data here

# %%
train1 = "/Users/vickiyew/Documents/Capstone/Data Set/train_FD001.txt"
train2 = "/Users/vickiyew/Documents/Capstone/Data Set/train_FD002.txt"
train3 = "/Users/vickiyew/Documents/Capstone/Data Set/train_FD003.txt"
train4 = "/Users/vickiyew/Documents/Capstone/Data Set/train_FD004.txt"

test1 = "/Users/vickiyew/Documents/Capstone/Data Set/test_FD001.txt"
test2 = "/Users/vickiyew/Documents/Capstone/Data Set/test_FD002.txt"
test3 = "/Users/vickiyew/Documents/Capstone/Data Set/test_FD003.txt"
test4 = "/Users/vickiyew/Documents/Capstone/Data Set/test_FD004.txt"

truth1 = "/Users/vickiyew/Documents/Capstone/Data Set/RUL_FD001.txt"
truth2 = "/Users/vickiyew/Documents/Capstone/Data Set/RUL_FD002.txt"
truth3 = "/Users/vickiyew/Documents/Capstone/Data Set/RUL_FD003.txt"
truth4 = "/Users/vickiyew/Documents/Capstone/Data Set/RUL_FD004.txt"

# %% [markdown]
# ## Read in Data

# %%
# Reading in the data (txt files)
import pandas as pd
# Train Datasets
train1_df = pd.read_csv(train1, sep=" ", header=None)
train2_df = pd.read_csv(train2, sep=" ", header=None)
train3_df = pd.read_csv(train3, sep=" ", header=None)
train4_df = pd.read_csv(train4, sep=" ", header=None)
# Test Datasets
test1_df = pd.read_csv(test1, sep=" ", header=None)
test2_df = pd.read_csv(test2, sep=" ", header=None)
test3_df = pd.read_csv(test3, sep=" ", header=None)
test4_df = pd.read_csv(test4, sep=" ", header=None)
# True RUL Data for the Test Sets
truth1_df = pd.read_csv(truth1, sep=" ", header=None)
truth2_df = pd.read_csv(truth2, sep=" ", header=None)
truth3_df = pd.read_csv(truth3, sep=" ", header=None)
truth4_df = pd.read_csv(truth4, sep=" ", header=None)

# %% [markdown]
# ## Data Preprocessing
# > * Drop last 2 columns (they are empty)
# > * Rename columns into readable forms
# > * Add RUL labels into the train datasets

# %%
# drop columns 
train1_df.drop(train1_df.columns[[26, 27]], axis=1, inplace=True)
test1_df.drop(test1_df.columns[[26, 27]], axis=1, inplace=True)
truth1_df.drop(truth1_df.columns[[1]], axis=1, inplace=True)

train2_df.drop(train2_df.columns[[26, 27]], axis=1, inplace=True)
test2_df.drop(test2_df.columns[[26, 27]], axis=1, inplace=True)
truth2_df.drop(truth2_df.columns[[1]], axis=1, inplace=True)

train3_df.drop(train3_df.columns[[26, 27]], axis=1, inplace=True)
test3_df.drop(test3_df.columns[[26, 27]], axis=1, inplace=True)
truth3_df.drop(truth3_df.columns[[1]], axis=1, inplace=True)

train4_df.drop(train4_df.columns[[26, 27]], axis=1, inplace=True)
test4_df.drop(test4_df.columns[[26, 27]], axis=1, inplace=True)
truth4_df.drop(truth4_df.columns[[1]], axis=1, inplace=True)

# %%
# Rename columns into readable forms, namely, by: 
# [Engine ID, Cycle, 3 Operational Settings, 21 Sensors]


train1_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
train1_df = train1_df.sort_values(['id','cycle'])


test1_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']


train2_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
train2_df = train2_df.sort_values(['id','cycle'])


test2_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']


train3_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
train3_df = train3_df.sort_values(['id','cycle'])


test3_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']


train4_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']
train4_df = train4_df.sort_values(['id','cycle'])


test4_df.columns = ['id', 'cycle', 'setting1', 'setting2', 'setting3', 's1', 's2', 's3',
                     's4', 's5', 's6', 's7', 's8', 's9', 's10', 's11', 's12', 's13', 's14',
                     's15', 's16', 's17', 's18', 's19', 's20', 's21']

# %% [markdown]
# ## Deriving RUL for Training Sets
# > RUL (of each row/instance of each Engine ID) = Maximum cycle length for each Engine ID - current cycle length (at each row/instance of each Engine ID)

# %%
# Derive the RUL for the Train Datasets

def extract_rul(data, factor = 0):

    # Get the total number of cycles for each unit, i.e. Each Engine ID
    rul = pd.DataFrame(data.groupby('id')['cycle'].max()).reset_index()
    rul.columns = ['id', 'max']

    # Merge the maximum cycle into the original dataframe
    data = data.merge(rul, on=['id'], how='left')

    # Actual calculation of RUL as provided in the equation above
    data['RUL'] = data['max'] - data['cycle']

    # Drop the 'max' column, which is now redundant
    data.drop(columns=['max'], axis = 1, inplace = True)
  
    return data[data['cycle'] > factor]

# Apply the function on the training data
train1_df = extract_rul(train1_df, factor = 0)
train2_df = extract_rul(train2_df, factor = 0)
train3_df = extract_rul(train3_df, factor = 0)
train4_df = extract_rul(train4_df, factor = 0)

# %% [markdown]
# ## FD001

# %% [markdown]
# ## Graphical Univariate Analysis

# %% [markdown]
# > Plot Histogram of RUL to get distribution of RUL
#
# > Findings: left skewed, most engines' RUL is about 180-200 cycles.

# %%
import matplotlib.pyplot as plt
df_max_rul = train1_df[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(5,5))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# > Correlation between variables

# %%
# Compute the correlation matrix
import numpy as np
import seaborn as sns
new_train = train1_df.drop(['id', 'cycle'], axis = 1) 
corr = new_train.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})

## can see from the corr matrix x-axis that settings 1 to 3 are mostly white. <i.e. settings 1 to 3 have little to no correlation>

# %% [markdown]
# ## Identifying Trends with Target Variable (RUL) with scatterplots
# > Findings: Some sensors do not vary with RUL, some sensors show an apparent increase/decrease trend with RUL

# %%
for column in train1_df.columns:
    counter = 1
    plt.figure()
    plt.subplot(3, 2, counter)
    counter += 1
    plt.scatter(train1_df[column], train1_df['RUL'])
    plt.title('correlation between '+column+' and RUL')
    plt.xlabel('RUL')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ## Correlation of Features with RUL
# > Some features show strong correlation with RUL

# %%
plt.figure(figsize=(8,8))
heatmap = sns.heatmap(train_df.corr()[['RUL']].sort_values(by='RUL', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with RUL', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# ## Correlation Analysis between Grouped Features

# %%
speed = ['s8', 's9', 's13', 's14']
temp = ['s2', 's3', 's4']
ratio = ['s12', 's15']
bleed = ['s17', 's20']
pressure = ['s7', 's11']

# %%
print(train1_df[speed].corr())
print(train1_df[temp].corr())
print(train1_df[ratio].corr())
print(train1_df[bleed].corr())
print(train1_df[pressure].corr())
# Out:
#            s8        s9       s13       s14
# s8   1.000000 -0.032091  0.826084 -0.144787
# s9  -0.032091  1.000000 -0.034763  0.963157
# s13  0.826084 -0.034763  1.000000 -0.147036
# s14 -0.144787  0.963157 -0.147036  1.000000
#           s2        s3        s4
# s2  1.000000  0.602610  0.714949
# s3  0.602610  1.000000  0.678413
# s4  0.714949  0.678413  1.000000
#           s12       s15
# s12  1.000000 -0.766052
# s15 -0.766052  1.000000
#           s17       s20
# s17  1.000000 -0.651021
# s20 -0.651021  1.000000
#            s7       s11
# s7   1.000000 -0.822805
# s11 -0.822805  1.000000

# %%
## Function for Correlation Heatmap
def heatmap(x, y, **kwargs):
    if 'color' in kwargs:
        color = kwargs['color']
    else:
        color = [1]*len(x)

    if 'palette' in kwargs:
        palette = kwargs['palette']
        n_colors = len(palette)
    else:
        n_colors = 256 # Use 256 colors for the diverging color palette
        palette = sns.color_palette("Blues", n_colors) 

    if 'color_range' in kwargs:
        color_min, color_max = kwargs['color_range']
    else:
        color_min, color_max = min(color), max(color) # Range of values that will be mapped to the palette, i.e. min and max possible correlation

    def value_to_color(val):
        if color_min == color_max:
            return palette[-1]
        else:
            val_position = float((val - color_min)) / (color_max - color_min) # position of value in the input range, relative to the length of the input range
            val_position = min(max(val_position, 0), 1) # bound the position betwen 0 and 1
            ind = int(val_position * (n_colors - 1)) # target index in the color palette
            return palette[ind]

    if 'size' in kwargs:
        size = kwargs['size']
    else:
        size = [1]*len(x)

    if 'size_range' in kwargs:
        size_min, size_max = kwargs['size_range'][0], kwargs['size_range'][1]
    else:
        size_min, size_max = min(size), max(size)

    size_scale = kwargs.get('size_scale', 500)

    def value_to_size(val):
        if size_min == size_max:
            return 1 * size_scale
        else:
            val_position = (val - size_min) * 0.99 / (size_max - size_min) + 0.01 # position of value in the input range, relative to the length of the input range
            val_position = min(max(val_position, 0), 1) # bound the position betwen 0 and 1
            return val_position * size_scale
    if 'x_order' in kwargs: 
        x_names = [t for t in kwargs['x_order']]
    else:
        x_names = [t for t in sorted(set([v for v in x]))]
    x_to_num = {p[1]:p[0] for p in enumerate(x_names)}

    if 'y_order' in kwargs: 
        y_names = [t for t in kwargs['y_order']]
    else:
        y_names = [t for t in sorted(set([v for v in y]))]
    y_to_num = {p[1]:p[0] for p in enumerate(y_names)}

    plot_grid = plt.GridSpec(1, 15, hspace=0.2, wspace=0.1) # Setup a 1x10 grid
    ax = plt.subplot(plot_grid[:,:-1]) # Use the left 14/15ths of the grid for the main plot

    marker = kwargs.get('marker', 's')

    kwargs_pass_on = {k:v for k,v in kwargs.items() if k not in [
         'color', 'palette', 'color_range', 'size', 'size_range', 'size_scale', 'marker', 'x_order', 'y_order', 'xlabel', 'ylabel'
    ]}

    ax.scatter(
        x=[x_to_num[v] for v in x],
        y=[y_to_num[v] for v in y],
        marker=marker,
        s=[value_to_size(v) for v in size], 
        c=[value_to_color(v) for v in color],
        **kwargs_pass_on
    )
    ax.set_xticks([v for k,v in x_to_num.items()])
    ax.set_xticklabels([k for k in x_to_num], rotation=45, horizontalalignment='right')
    ax.set_yticks([v for k,v in y_to_num.items()])
    ax.set_yticklabels([k for k in y_to_num])

    ax.grid(False, 'major')
    ax.grid(True, 'minor')
    ax.set_xticks([t + 0.5 for t in ax.get_xticks()], minor=True)
    ax.set_yticks([t + 0.5 for t in ax.get_yticks()], minor=True)

    ax.set_xlim([-0.5, max([v for v in x_to_num.values()]) + 0.5])
    ax.set_ylim([-0.5, max([v for v in y_to_num.values()]) + 0.5])
    ax.set_facecolor('#F1F1F1')

    ax.set_xlabel(kwargs.get('xlabel', ''))
    ax.set_ylabel(kwargs.get('ylabel', ''))

    # Add color legend on the right side of the plot
    if color_min < color_max:
        ax = plt.subplot(plot_grid[:,-1]) # Use the rightmost column of the plot

        col_x = [0]*len(palette) # Fixed x coordinate for the bars
        bar_y=np.linspace(color_min, color_max, n_colors) # y coordinates for each of the n_colors bars

        bar_height = bar_y[1] - bar_y[0]
        ax.barh(
            y=bar_y,
            width=[5]*len(palette), # Make bars 5 units wide
            left=col_x, # Make bars start at 0
            height=bar_height,
            color=palette,
            linewidth=0
        )
        ax.set_xlim(1, 2) # Bars are going from 0 to 5, so lets crop the plot somewhere in the middle
        ax.grid(False) # Hide grid
        ax.set_facecolor('white') # Make background white
        ax.set_xticks([]) # Remove horizontal ticks
        ax.set_yticks(np.linspace(min(bar_y), max(bar_y), 3)) # Show vertical ticks for min, middle and max
        ax.yaxis.tick_right() # Show vertical ticks on the right 


def corrplot(data, size_scale=500, marker='s'):
    corr = pd.melt(data.reset_index(), id_vars='index').replace(np.nan, 0)
    corr.columns = ['x', 'y', 'value']
    heatmap(
        corr['x'], corr['y'],
        color=corr['value'], color_range=[-1, 1],
        palette=sns.diverging_palette(20, 220, n=256),
        size=corr['value'].abs(), size_range=[0,1],
        marker=marker,
        x_order=data.columns,
        y_order=data.columns[::-1],
        size_scale=size_scale
    )

# %% [markdown]
# ## Correlation Analysis amongst Grouped Features

# %%
# Speed
corrplot(train1_df[speed].corr(), size_scale=300);

# %%
# Temp
corrplot(train1_df[temp].corr(), size_scale=300);

# %%
# Ratio
corrplot(train1_df[ratio].corr(), size_scale=300);

# %%
# Bleed
corrplot(train1_df[bleed].corr(), size_scale=300);

# %%
# Pressure
corrplot(train1_df[pressure].corr(), size_scale=300);

# %% [markdown]
# ## Statistical Summary of Numerical Variables

# %%
train_df.describe()
# Out:
#                  id         cycle  ...           s21           RUL
# count  20631.000000  20631.000000  ...  20631.000000  20631.000000
# mean      51.506568    108.807862  ...     23.289705    107.807862
# std       29.227633     68.880990  ...      0.108251     68.880990
# min        1.000000      1.000000  ...     22.894200      0.000000
# 25%       26.000000     52.000000  ...     23.221800     51.000000
# 50%       52.000000    104.000000  ...     23.297900    103.000000
# 75%       77.000000    156.000000  ...     23.366800    155.000000
# max      100.000000    362.000000  ...     23.618400    361.000000
#
# [8 rows x 27 columns]

# %% [markdown]
# ## Identification of Data Types and Missing Values
# > Findings: no missing values, data types as shown

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20631 entries, 0 to 20630
# Data columns (total 27 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        20631 non-null  int64
#  1   cycle     20631 non-null  int64
#  2   setting1  20631 non-null  float64
#  3   setting2  20631 non-null  float64
#  4   setting3  20631 non-null  float64
#  5   s1        20631 non-null  float64
#  6   s2        20631 non-null  float64
#  7   s3        20631 non-null  float64
#  8   s4        20631 non-null  float64
#  9   s5        20631 non-null  float64
#  10  s6        20631 non-null  float64
#  11  s7        20631 non-null  float64
#  12  s8        20631 non-null  float64
#  13  s9        20631 non-null  float64
#  14  s10       20631 non-null  float64
#  15  s11       20631 non-null  float64
#  16  s12       20631 non-null  float64
#  17  s13       20631 non-null  float64
#  18  s14       20631 non-null  float64
# ...

# %% [markdown]
# ## FD002

# %% [markdown]
# ## Graphical Univariate Analysis

# %% [markdown]
# > Plot Histogram of RUL to get distribution of RUL
#
# > Findings: left skewed, most engines' RUL is about 180-200 cycles.

# %%
import matplotlib.pyplot as plt
df_max_rul = train2_df[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(5,5))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ## Correlation Analysis

# %% [markdown]
# > Correlation between variables

# %%
# Compute the correlation matrix
import numpy as np
import seaborn as sns
new_train = train2_df.drop(['id', 'cycle'], axis = 1) 
corr = new_train.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})

## can see from the corr matrix x-axis that settings 1 to 3 are mostly white. <i.e. settings 1 to 3 have little to no correlation>

# %% [markdown]
# ## Identifying Trends with Target Variable (RUL) with scatterplots
# > Findings: Sensors do not show apparent trends with RUL

# %%
for column in train2_df.columns:
    counter = 1
    plt.figure()
    plt.subplot(3, 2, counter)
    counter += 1
    plt.scatter(train2_df[column], train2_df['RUL'])
    plt.title('correlation between '+column+' and RUL')
    plt.xlabel('RUL')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ## Correlation of Features with RUL
# > Features do not show strong correlation with RUL

# %%
plt.figure(figsize=(8,8))
heatmap = sns.heatmap(train2_df.corr()[['RUL']].sort_values(by='RUL', ascending=False), vmin=-1, vmax=1, annot=True, cmap='BrBG')
heatmap.set_title('Features Correlating with RUL', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# ## Correlation Analysis between Grouped Features

# %%
# Speed
corrplot(train1_df[speed].corr(), size_scale=300);

# %%
# Ratio
corrplot(train1_df[ratio].corr(), size_scale=300);

# %%
# Bleed
corrplot(train1_df[bleed].corr(), size_scale=300);

# %%
# Temperature
corrplot(train1_df[temp].corr(), size_scale=300);

# %%
# Pressure
corrplot(train1_df[pressure].corr(), size_scale=300);

# %% [markdown]
# ## FD003

# %% [markdown]
# ## Graphical Univariate Analysis
# > Plot Histogram of RUL to get distribution of RUL
#
# > Findings: left skewed, most engines' RUL is about 180 cycles.

# %%
import matplotlib.pyplot as plt
df_max_rul = train3_df[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(5,5))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ## Multivariate Analysis
# ## Correlation Analysis
# > Correlation between variables

# %%
# Compute the correlation matrix
import numpy as np
import seaborn as sns
new_train = train3_df.drop(['id', 'cycle'], axis = 1) 
corr = new_train.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})

## can see from the corr matrix x-axis that settings 1 to 3 are mostly white. <i.e. settings 1 to 3 have little to no correlation>

# %% [markdown]
# ## Identifying Trends with Target Variable (RUL) with scatterplots
# > Findings: Sensors show apparent trends of increase/decrease with RUL, while others show no variation with RUL.

# %%
for column in train3_df.columns:
    counter = 1
    plt.figure()
    plt.subplot(3, 2, counter)
    counter += 1
    plt.scatter(train3_df[column], train3_df['RUL'])
    plt.title('correlation between '+column+' and RUL')
    plt.xlabel('RUL')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ## Correlation Analysis between Grouped Features

# %%
# Speed
corrplot(train1_df[speed].corr(), size_scale=300);

# %%
# Temperature
corrplot(train1_df[temp].corr(), size_scale=300);

# %%
# Bleed
corrplot(train1_df[bleed].corr(), size_scale=300);

# %%
# Ratio
corrplot(train1_df[ratio].corr(), size_scale=300);

# %%
# Pressure
corrplot(train1_df[pressure].corr(), size_scale=300);

# %% [markdown]
# ## FD004

# %% [markdown]
# ## Graphical Univariate Analysis
# > Plot Histogram of RUL to get distribution of RUL
#
# > Findings: left skewed, most engines' RUL is about 180-200 cycles.

# %%
import matplotlib.pyplot as plt
df_max_rul = train4_df[['id', 'RUL']].groupby('id').max().reset_index()
df_max_rul['RUL'].hist(bins=15, figsize=(5,5))
plt.xlabel('RUL')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# ## Multivariate Analysis
# ## Correlation Analysis
# > Correlation between variables

# %%
# Compute the correlation matrix
import numpy as np
import seaborn as sns
new_train = train4_df.drop(['id', 'cycle'], axis = 1) 
corr = new_train.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": 1})

## can see from the corr matrix x-axis that settings 1 to 3 are mostly white. <i.e. settings 1 to 3 have little to no correlation>

# %% [markdown]
# ## Identifying Trends with Target Variable (RUL) with scatterplots
# > Findings: Sensors do not show apparent trends with RUL.

# %%
for column in train4_df.columns:
    counter = 1
    plt.figure()
    plt.subplot(3, 2, counter)
    counter += 1
    plt.scatter(train4_df[column], train4_df['RUL'])
    plt.title('correlation between '+column+' and RUL')
    plt.xlabel('RUL')
    plt.ylabel(column)
    plt.show()

# %% [markdown]
# ## Correlation Analysis between Grouped Features

# %%
# Speed
corrplot(train1_df[speed].corr(), size_scale=300);

# %%
# Ratio
corrplot(train1_df[ratio].corr(), size_scale=300);

# %%
# Bleed
corrplot(train1_df[bleed].corr(), size_scale=300);

# %%
# Temp
corrplot(train1_df[temp].corr(), size_scale=300);

# %%
# pressure
corrplot(train1_df[pressure].corr(), size_scale=300);
